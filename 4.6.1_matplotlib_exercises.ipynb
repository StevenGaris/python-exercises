# %%
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y = x^2 − x + 2
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = list(range(-5,5))
y = [((n**2) - n + 2) for n in x]

plt.scatter(x,y)
plt.plot(x,y,ls=":")

plt.text(-.25, 3 , 'Origin', fontsize=10, color='blue')

plt.show()

# %%
x = list(range(0,10))
y = [math.sqrt(n) for n in x]
plt.plot(x,y,c='r')
plt.show()

# %%
x = list(range(0,10))
y = [n ** 3 for n in x]
plt.plot(x,y,c='b')
plt.show()

# %%
x = list(range(0,10))
y = [math.tan(n) for n in x]
plt.plot(x,y,c='g')
plt.show()

# %%
x = list(range(0,10))
y = [(2**n) for n in x]
plt.plot(x,y,c='orange')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.suptitle('Functions Subplot')

r = list(range(0,100))
x = [math.sqrt(n) for n in r]
y = [n**3 for n in r]
z = [math.tan(n) for n in r]
s = [(2**n) for n in r]

plt.subplot(221)
plt.plot(r,x,c='r')
plt.title('$y=√x$')

plt.subplot(222)
plt.plot(r,y,c='b')
plt.title('$y=x^3$')

plt.subplot(223)
plt.plot(r,z,c='g')
plt.title('$y=tan(x)$')


plt.subplot(224)
plt.plot(r,s,c='orange')
plt.title('$y = 2^x$')


plt.show()

# %%
plt.figure(figsize=(10,10))
plt.suptitle('Functions Combined')

r = list(range(0,100))
x = [math.sqrt(n) for n in r]
y = [n**3 for n in r]
z = [math.tan(n) for n in r]
s = [(2**n) for n in r]

plt.xlim(-2.5,25)
plt.ylim(-20,20)
plt.grid(True)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')


plt.plot(r, x, c='r', label='$y=√x$')
plt.plot(r, y, c='b', label='$y=x^3$')
plt.plot(r, z, c='g', label='$y=tan(x)$')
plt.plot(r, s, c='orange', label='$y = 2^x$')

plt.legend(loc='best')
plt.show()

# %%
import math

plt.xlim(-1,20)
plt.ylim(-1,6)
plt.grid(True)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')


s1 = plt.hlines(y=5, xmin=1, xmax=3, linewidth=2, color='r')
s2 = plt.hlines(y=3, xmin=1, xmax=3, linewidth=2, color='r')
s3 = plt.hlines(y=1, xmin=1, xmax=3, linewidth=2, color='r')
s4 = plt.vlines(x=1, ymin=3, ymax=5, linewidth=2, color='r')
s5 = plt.vlines(x=3, ymin=1, ymax=3, linewidth=2, color='r')

t1 = plt.hlines(y=5, xmin=4, xmax=6, linewidth=2, color='orange')
t2 = plt.vlines(x=5, ymin=1, ymax=5, linewidth=2, color='orange')

e1 = plt.hlines(y=5, xmin=7, xmax=9, linewidth=2, color='y')
e2 = plt.hlines(y=3, xmin=7, xmax=8, linewidth=2, color='y')
e3 = plt.hlines(y=1, xmin=7, xmax=9, linewidth=2, color='y')
e4 = plt.vlines(x=7, ymin=1, ymax=5, linewidth=2, color='y')

# v?


e5 = plt.hlines(y=5, xmin=13, xmax=15, linewidth=2, color='b')
e6 = plt.hlines(y=3, xmin=13, xmax=14, linewidth=2, color='b')
e7 = plt.hlines(y=1, xmin=13, xmax=15, linewidth=2, color='b')
e8 = plt.vlines(x=13, ymin=1, ymax=5, linewidth=2, color='b')

n1 = plt.vlines(x=16, ymin=1, ymax=5, linewidth=2, color='purple')
# n2 =
n3 = plt.vlines(x=18, ymin=1, ymax=5, linewidth=2, color='purple')


plt.show()
